# %%
import json
import pandas as pd
import numpy as np
import re

# %% [markdown]
# # create a file path so code is more dynamic if location of data changes

# %%
file_dir = "C:\\Users\\Frank Bucalo\\Desktop\\classwork\\Movies-ETL\\"

# %%
f'{file_dir}wikipedia-movies.json'
# Out:
# 'C:\\Users\\Frank Bucalo\\Desktop\\classwork\\Movies-ETL\\wikipedia-movies.json'

# %% [markdown]
# # load JSON into a list of dictionaries
# > load( )
#
# use "with open" to both & close the file while in use

# %%
with open(f'{file_dir}wikipedia-movies.json', mode='r') as file:
    wiki_movies_raw = json.load(file)

# %%
len(wiki_movies_raw)
# Out:
# 7311

# %% [markdown]
# # use index slices to review the dictionaries

# %%
# First 5 records
wiki_movies_raw[:5]
# Out:
# [{'url': 'https://en.wikipedia.org/wiki/The_Adventures_of_Ford_Fairlane',
#   'year': 1990,
#   'imdb_link': 'https://www.imdb.com/title/tt0098987/',
#   'title': 'The Adventures of Ford Fairlane',
#   'Directed by': 'Renny Harlin',
#   'Produced by': ['Steve Perry', 'Joel Silver'],
#   'Screenplay by': ['David Arnott', 'James Cappe', 'Daniel Waters'],
#   'Story by': ['David Arnott', 'James Cappe'],
#   'Based on': ['Characters', 'by Rex Weiner'],
#   'Starring': ['Andrew Dice Clay',
#    'Wayne Newton',
#    'Priscilla Presley',
#    'Lauren Holly',
#    'Morris Day',
#    'Robert Englund',
#    "Ed O'Neill"],
#   'Narrated by': 'Andrew "Dice" Clay',
#   'Music by': ['Cliff Eidelman', 'Yello'],
#   'Cinematography': 'Oliver Wood',
#   'Edited by': 'Michael Tronick',
#   'Productioncompany ': 'Silver Pictures',
#   'Distributed by': '20th Century Fox',
#   'Release date': ['July 11, 1990', '(', '1990-07-11', ')'],
#   'Running time': '102 minutes',
#   'Country': 'United States',
# ...

# %%
# Last 5 records
wiki_movies_raw[-5:]
# Out:
# [{'url': 'https://en.wikipedia.org/wiki/Holmes_%26_Watson',
#   'year': 2018,
#   'imdb_link': 'https://www.imdb.com/title/tt1255919/',
#   'title': 'Holmes & Watson',
#   'Directed by': 'Etan Cohen',
#   'Produced by': ['Will Ferrell',
#    'Adam McKay',
#    'Jimmy Miller',
#    'Clayton Townsend'],
#   'Screenplay by': 'Etan Cohen',
#   'Based on': ['Sherlock Holmes',
#    'and',
#    'Dr. Watson',
#    'by',
#    'Sir Arthur Conan Doyle'],
#   'Starring': ['Will Ferrell',
#    'John C. Reilly',
#    'Rebecca Hall',
#    'Rob Brydon',
#    'Steve Coogan',
#    'Ralph Fiennes'],
#   'Music by': 'Mark Mothersbaugh',
#   'Cinematography': 'Oliver Wood',
#   'Edited by': 'Dean Zimmerman',
#   'Productioncompanies ': ['Columbia Pictures',
#    'Gary Sanchez Productions',
#    'Mosaic Media Group',
#    'Mimran Schur Pictures'],
#   'Distributed by': 'Sony Pictures Releasing',
#   'Release date': ['December 25, 2018',
#    '(',
#    '2018-12-25',
#    ')',
#    '(United States)'],
# ...

# %%
# Some records in the middle
wiki_movies_raw[3600:3605]
# Out:
# [{'url': 'https://en.wikipedia.org/wiki/Benji:_Off_the_Leash!',
#   'year': 2004,
#   'imdb_link': 'https://www.imdb.com/title/tt0315273/',
#   'title': 'Benji: Off the Leash!',
#   'Directed by': 'Joe Camp',
#   'Written by': 'Joe Camp',
#   'Starring': ['Benji', 'Nick Whitaker', 'Shaggy', 'Gypsy the Cockatoo'],
#   'Music by': 'Antonio di Lorenzo',
#   'Productioncompany ': 'Mulberry Square Productions',
#   'Distributed by': 'Mulberry Square Productions',
#   'Release date': ['March 26, 2004', '(', '2004-03-26', ')'],
#   'Running time': '97 min',
#   'Country': 'United States',
#   'Language': 'English',
#   'Box office': '$3,817,362'},
#  {'url': 'https://en.wikipedia.org/wiki/The_Best_Thief_in_the_World',
#   'year': 2004,
#   'imdb_link': 'https://www.imdb.com/title/tt0389796/',
#   'title': 'The Best Thief in the World',
#   'Directed by': 'Jacob Kornbluth',
#   'Produced by': ['Tim Perrell', 'Nicola Usborne'],
#   'Written by': 'Jacob Kornbluth',
# ...

# %%
movies_meta = pd.read_csv(f'{file_dir}movies_metadata.csv', low_memory=False)
ratings = pd.read_csv(f'{file_dir}ratings.csv')

# %%
movies_meta.head()
# Out:
#    adult                              belongs_to_collection    budget  \
# 0  False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1  False                                                NaN  65000000
# 2  False  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3  False                                                NaN  16000000
# 4  False  {'id': 96871, 'name': 'Father of the Bride Col...         0
#
#                                               genres  \
# 0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# 3  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 4                     [{'id': 35, 'name': 'Comedy'}]
#
#                                homepage     id    imdb_id original_language  \
# 0  http://toystory.disney.com/toy-story    862  tt0114709                en
# ...

# %% [markdown]
# # sample to ensure data import looks correct
# > sample( )

# %%
movies_meta.sample(n=5)
# Out:
#        adult belongs_to_collection   budget  \
# 10997  False                   NaN        0
# 20483  False                   NaN        0
# 5442   False                   NaN  9000000
# 24679  False                   NaN        0
# 22045  False                   NaN  3200000
#
#                                                   genres homepage      id  \
# 10997                      [{'id': 18, 'name': 'Drama'}]      NaN   38344
# 20483                                                 []      NaN  359353
# 5442   [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...      NaN    9685
# 24679  [{'id': 35, 'name': 'Comedy'}, {'id': 10749, '...      NaN   91580
# 22045  [{'id': 28, 'name': 'Action'}, {'id': 80, 'nam...      NaN   43213
#
#          imdb_id original_language    original_title  \
# 10997  tt0410400                en    On a Clear Day
# 20483  tt0198999                en     The Scarecrow
# 5442   tt0280760                en    Igby Goes Down
# ...

# %%
movies_meta.tail()
# Out:
#        adult belongs_to_collection budget  \
# 45461  False                   NaN      0
# 45462  False                   NaN      0
# 45463  False                   NaN      0
# 45464  False                   NaN      0
# 45465  False                   NaN      0
#
#                                                   genres  \
# 45461  [{'id': 18, 'name': 'Drama'}, {'id': 10751, 'n...
# 45462                      [{'id': 18, 'name': 'Drama'}]
# 45463  [{'id': 28, 'name': 'Action'}, {'id': 18, 'nam...
# 45464                                                 []
# 45465                                                 []
#
#                                    homepage      id    imdb_id  \
# 45461  http://www.imdb.com/title/tt6209470/  439050  tt6209470
# 45462                                   NaN  111109  tt2028550
# 45463                                   NaN   67758  tt0303758
# 45464                                   NaN  227506  tt0008536
# ...

# %%
ratings.head()
# Out:
#    userId  movieId  rating   timestamp
# 0       1      110     1.0  1425941529
# 1       1      147     4.5  1425942435
# 2       1      858     5.0  1425941523
# 3       1     1221     5.0  1425941546
# 4       1     1246     5.0  1425941556

# %%
ratings.sample(n=5)
# Out:
#           userId  movieId  rating   timestamp
# 17957028  186460      357     4.0   835777626
# 3952640    41131     8827     3.5  1228435970
# 4717532    48498      708     3.0   938596851
# 16280322  169170     6711     5.0  1206520075
# 23456269  243453     3809     4.0  1093045266

# %%
ratings.tail()
# Out:
#           userId  movieId  rating   timestamp
# 26024284  270896    58559     5.0  1257031564
# 26024285  270896    60069     5.0  1257032032
# 26024286  270896    63082     4.5  1257031764
# 26024287  270896    64957     4.5  1257033990
# 26024288  270896    71878     2.0  1257031858

# %% [markdown]
# # convert to DataFrame for further inspection

# %%
wiki_movies_df = pd.DataFrame(wiki_movies_raw)

wiki_movies_df.head(10)
# Out:
#                                                  url    year  \
# 0  https://en.wikipedia.org/wiki/The_Adventures_o...  1990.0
# 1  https://en.wikipedia.org/wiki/After_Dark,_My_S...  1990.0
# 2   https://en.wikipedia.org/wiki/Air_America_(film)  1990.0
# 3    https://en.wikipedia.org/wiki/Alice_(1990_film)  1990.0
# 4      https://en.wikipedia.org/wiki/Almost_an_Angel  1990.0
# 5        https://en.wikipedia.org/wiki/The_Ambulance  1990.0
# 6  https://en.wikipedia.org/wiki/American_Dream_(...  1990.0
# 7  https://en.wikipedia.org/wiki/American_Ninja_4...  1990.0
# 8     https://en.wikipedia.org/wiki/Andre%27s_Mother  1990.0
# 9    https://en.wikipedia.org/wiki/Angel_Town_(film)  1990.0
#
#                                imdb_link                               title  \
# 0  https://www.imdb.com/title/tt0098987/     The Adventures of Ford Fairlane
# 1  https://www.imdb.com/title/tt0098994/                After Dark, My Sweet
# ...

# %% [markdown]
# # convert columns to a list to more easily view
# > .tolist( )

# %%
wiki_movies_df.columns.tolist()
# Out:
# ['url',
#  'year',
#  'imdb_link',
#  'title',
#  'Directed by',
#  'Produced by',
#  'Screenplay by',
#  'Story by',
#  'Based on',
#  'Starring',
#  'Narrated by',
#  'Music by',
#  'Cinematography',
#  'Edited by',
#  'Productioncompany ',
#  'Distributed by',
#  'Release date',
#  'Running time',
#  'Country',
#  'Language',
#  'Budget',
#  'Box office',
#  'Written by',
#  'Genre',
#  'Theme music composer',
#  'Country of origin',
#  'Original language(s)',
#  'Producer(s)',
#  'Editor(s)',
#  'Production company(s)',
#  'Original network',
#  'Original release',
#  'Productioncompanies ',
#  'Executive producer(s)',
#  'Production location(s)',
#  'Distributor',
#  'Picture format',
#  'Audio format',
#  'Voices of',
#  'Followed by',
#  'Composer(s)',
#  'Created by',
#  'Also known as',
#  'Opening theme',
#  'No. of episodes',
#  'Preceded by',
#  'Author',
#  'Publisher',
#  'Publication date',
#  'Media type',
#  'Pages',
#  'ISBN',
#  'OCLC',
#  'LC Class',
# ...

# %% [markdown]
# # use list comprehensions to filter

# %%
wiki_movies = [movie for movie in wiki_movies_raw
    if ('Director' in movie or 'Directed by' in movie)
    and 'imdb_link' in movie]

len(wiki_movies)
# Out:
# 7080

# %%
filtered_movies_df = pd.DataFrame(wiki_movies)

filtered_movies_df.head(10)
# Out:
#                                                  url  year  \
# 0  https://en.wikipedia.org/wiki/The_Adventures_o...  1990
# 1  https://en.wikipedia.org/wiki/After_Dark,_My_S...  1990
# 2   https://en.wikipedia.org/wiki/Air_America_(film)  1990
# 3    https://en.wikipedia.org/wiki/Alice_(1990_film)  1990
# 4      https://en.wikipedia.org/wiki/Almost_an_Angel  1990
# 5        https://en.wikipedia.org/wiki/The_Ambulance  1990
# 6  https://en.wikipedia.org/wiki/American_Dream_(...  1990
# 7  https://en.wikipedia.org/wiki/American_Ninja_4...  1990
# 8     https://en.wikipedia.org/wiki/Andre%27s_Mother  1990
# 9    https://en.wikipedia.org/wiki/Angel_Town_(film)  1990
#
#                                imdb_link                               title  \
# 0  https://www.imdb.com/title/tt0098987/     The Adventures of Ford Fairlane
# 1  https://www.imdb.com/title/tt0098994/                After Dark, My Sweet
# 2  https://www.imdb.com/title/tt0099005/                         Air America
# ...

# %%
wiki_movies = [movie for movie in wiki_movies_raw
               if ('Director' in movie or 'Directed by' in movie)
                   and 'imdb_link' in movie
                   and 'No. of episodes' not in movie]

# %%
only_movies_df = pd.DataFrame(wiki_movies)

only_movies_df.head(10)
# Out:
#                                                  url  year  \
# 0  https://en.wikipedia.org/wiki/The_Adventures_o...  1990
# 1  https://en.wikipedia.org/wiki/After_Dark,_My_S...  1990
# 2   https://en.wikipedia.org/wiki/Air_America_(film)  1990
# 3    https://en.wikipedia.org/wiki/Alice_(1990_film)  1990
# 4      https://en.wikipedia.org/wiki/Almost_an_Angel  1990
# 5        https://en.wikipedia.org/wiki/The_Ambulance  1990
# 6  https://en.wikipedia.org/wiki/American_Dream_(...  1990
# 7  https://en.wikipedia.org/wiki/American_Ninja_4...  1990
# 8     https://en.wikipedia.org/wiki/Andre%27s_Mother  1990
# 9    https://en.wikipedia.org/wiki/Angel_Town_(film)  1990
#
#                                imdb_link                               title  \
# 0  https://www.imdb.com/title/tt0098987/     The Adventures of Ford Fairlane
# 1  https://www.imdb.com/title/tt0098994/                After Dark, My Sweet
# 2  https://www.imdb.com/title/tt0099005/                         Air America
# ...

# %% [markdown]
# # create a function to perform cleaning
# ### create a non-destructive copy

# %%
def clean_movie(movie):
    movie = dict(movie)
    return movie

# %%
only_movies_df[only_movies_df['Arabic'].notnull()]
# Out:
#                                                   url  year  \
# 6834  https://en.wikipedia.org/wiki/The_Insult_(film)  2018
# 7058   https://en.wikipedia.org/wiki/Capernaum_(film)  2018
#
#                                   imdb_link       title    Directed by  \
# 6834  https://www.imdb.com/title/tt7048622/  The Insult   Ziad Doueiri
# 7058  https://www.imdb.com/title/tt8267604/   Capernaum  Nadine Labaki
#
#                                             Produced by  \
# 6834  [Rachid Bouchareb, Jean Bréhat, Julie Gayet, A...
# 7058                    [Michel Merkt, Khaled Mouzanar]
#
#                                           Screenplay by  \
# 6834                                                NaN
# 7058  [Nadine Labaki, Jihad Hojaily, Michelle Keserw...
#
#                                                Story by Based on  \
# 6834                                                NaN      NaN
# 7058  [Georges Khabbaz, Nadine Labaki, Michelle Kese...      NaN
#
# ...

# %%
only_movies_df['year'].value_counts()
# Out:
# 2006    403
# 2013    363
# 1997    342
# 1996    338
# 1995    295
# 2012    294
# 2007    290
# 1994    277
# 1990    261
# 2018    257
# 1998    235
# 2004    232
# 2017    232
# 2005    228
# 2002    226
# 2009    224
# 2003    220
# 2001    217
# 1999    216
# 1992    214
# 2014    210
# 2000    209
# 2008    207
# 2010    207
# 2011    199
# 1991    198
# 1993    196
# 2015    145
# 2016    141
# Name: year, dtype: int64

# %%
sorted(only_movies_df.columns.tolist())
# Out:
# ['Adaptation by',
#  'Also known as',
#  'Animation by',
#  'Arabic',
#  'Audio format',
#  'Based on',
#  'Box office',
#  'Budget',
#  'Cantonese',
#  'Chinese',
#  'Cinematography',
#  'Color process',
#  'Composer(s)',
#  'Country',
#  'Country of origin',
#  'Created by',
#  'Directed by',
#  'Director',
#  'Distributed by',
#  'Distributor',
#  'Edited by',
#  'Editor(s)',
#  'Executive producer(s)',
#  'Followed by',
#  'French',
#  'Genre',
#  'Hangul',
#  'Hebrew',
#  'Hepburn',
#  'Japanese',
#  'Label',
#  'Language',
#  'Length',
#  'Literally',
#  'Mandarin',
#  'McCune–Reischauer',
#  'Music by',
#  'Narrated by',
#  'Original language(s)',
#  'Original network',
#  'Original release',
#  'Original title',
#  'Picture format',
#  'Polish',
#  'Preceded by',
#  'Produced by',
#  'Producer',
#  'Producer(s)',
#  'Production company(s)',
#  'Production location(s)',
#  'Productioncompanies ',
#  'Productioncompany ',
#  'Recorded',
#  'Release date',
#  'Released',
# ...

# %%
only_movies_df['Polish'].value_counts()
# Out:
# Zimna wojna    1
# Name: Polish, dtype: int64

# %% [markdown]
# # functions in functions - scope
# ## consolidate columns
# > .pop( )
# >returns the value from the key: value pair

# %%
def clean_movie(movie):
    
    movie = dict(movie)
    alt_titles = {}
    
    # combine alternate titles into one list
    for key in ['Also known as','Arabic','Cantonese','Chinese','French',
                'Hangul','Hebrew','Hepburn','Japanese','Literally',
                'Mandarin','McCune–Reischauer','Original title','Polish',
                'Revised Romanization','Romanized','Russian',
                'Simplified','Traditional','Yiddish']:
        
        if key in movie:
            alt_titles[key] = movie[key]
            movie.pop(key)
    
    if len(alt_titles) > 0:
        movie['alt_titles'] = alt_titles
    
    # combining similar columns names
    def change_col_name(old_name, new_name):
        
        if old_name in movie:
            movie[new_name] = movie.pop(old_name)
        
    change_col_name('Directed by', 'Director')
    change_col_name('Country of origin', 'Country')
    change_col_name('Distributed by', 'Distributor')
    change_col_name('Edited by', 'Editor(s)')
    change_col_name('Produced by', 'Producer(s)')
    change_col_name('Producer', 'Producer(s)')
    change_col_name('Productioncompanies ', 'Production company(s)')
    change_col_name('Productioncompany ', 'Production company(s)')
    change_col_name('Original release', 'Release date')
    change_col_name('Released', 'Release date')
    change_col_name('Theme music composer', 'Composer(s)')
    
    return movie

clean_movies = [clean_movie(movie) for movie in wiki_movies]

# %%
wiki_movies_df = pd.DataFrame(clean_movies)

sorted(wiki_movies_df.columns.tolist())
# Out:
# ['Adaptation by',
#  'Animation by',
#  'Audio format',
#  'Based on',
#  'Box office',
#  'Budget',
#  'Cinematography',
#  'Color process',
#  'Composer(s)',
#  'Country',
#  'Created by',
#  'Director',
#  'Distributor',
#  'Editor(s)',
#  'Executive producer(s)',
#  'Followed by',
#  'Genre',
#  'Label',
#  'Language',
#  'Length',
#  'Music by',
#  'Narrated by',
#  'Original language(s)',
#  'Original network',
#  'Picture format',
#  'Preceded by',
#  'Producer(s)',
#  'Production company(s)',
#  'Production location(s)',
#  'Recorded',
#  'Release date',
#  'Running time',
#  'Screen story by',
#  'Screenplay by',
#  'Starring',
#  'Story by',
#  'Suggested by',
#  'Venue',
#  'Voices of',
#  'Written by',
#  'alt_titles',
#  'imdb_link',
#  'title',
#  'url',
#  'year']

# %% [markdown]
# # regex
# ### [RegExr](https://regexr.com/)
# > str.extract( )
# >takes in a regular expression pattern

# %%
wiki_movies_df['imdb_link'].head()

# regex would be "(tt\d{7})"

# ( ) -specify to look for 1 group of text
# \d -match a numerical digit
# { } -match the previous n times
# Out:
# 0    https://www.imdb.com/title/tt0098987/
# 1    https://www.imdb.com/title/tt0098994/
# 2    https://www.imdb.com/title/tt0099005/
# 3    https://www.imdb.com/title/tt0099012/
# 4    https://www.imdb.com/title/tt0099018/
# Name: imdb_link, dtype: object

# %%
# r -regular expressions use backslashes, which Python also uses for special characters 'r' tell Python that to treat as raw string of text
wiki_movies_df['IMDB_id'] = wiki_movies_df['imdb_link'].str.extract(r"(tt\d{7})")

print(len(wiki_movies_df))
# Out:
# 7076

# %%
wiki_movies_df['IMDB_id'].head()
# Out:
# 0    tt0098987
# 1    tt0098994
# 2    tt0099005
# 3    tt0099012
# 4    tt0099018
# Name: IMDB_id, dtype: object

# %%
# drop duplicates
wiki_movies_df.drop_duplicates(subset='IMDB_id', inplace=True)

print(len(wiki_movies_df))
# Out:
# 7033

# %%
wiki_movies_df.head()
# Out:
#                                                  url  year  \
# 0  https://en.wikipedia.org/wiki/The_Adventures_o...  1990
# 1  https://en.wikipedia.org/wiki/After_Dark,_My_S...  1990
# 2   https://en.wikipedia.org/wiki/Air_America_(film)  1990
# 3    https://en.wikipedia.org/wiki/Alice_(1990_film)  1990
# 4      https://en.wikipedia.org/wiki/Almost_an_Angel  1990
#
#                                imdb_link                            title  \
# 0  https://www.imdb.com/title/tt0098987/  The Adventures of Ford Fairlane
# 1  https://www.imdb.com/title/tt0098994/             After Dark, My Sweet
# 2  https://www.imdb.com/title/tt0099005/                      Air America
# 3  https://www.imdb.com/title/tt0099012/                            Alice
# 4  https://www.imdb.com/title/tt0099018/                  Almost an Angel
#
#                                 Screenplay by                     Story by  \
# 0  [David Arnott, James Cappe, Daniel Waters]  [David Arnott, James Cappe]
# ...

# %%
wiki_movies_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7033 entries, 0 to 7075
# Data columns (total 46 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   url                     7033 non-null   object
#  1   year                    7033 non-null   int64
#  2   imdb_link               7033 non-null   object
#  3   title                   7032 non-null   object
#  4   Screenplay by           2307 non-null   object
#  5   Story by                996 non-null    object
#  6   Based on                2181 non-null   object
#  7   Starring                6849 non-null   object
#  8   Narrated by             281 non-null    object
#  9   Music by                6440 non-null   object
#  10  Cinematography          6342 non-null   object
#  11  Release date            7001 non-null   object
#  12  Running time            6892 non-null   object
#  13  Country                 6797 non-null   object
# ...

# %% [markdown]
# # list comprehension on each column
# > .isnull( ) -return boolean
# > .sum() -add up all those booleans
# > if that sum is less than 90% of the length of the entire dataframe

# %%
[column for column in wiki_movies_df.columns if wiki_movies_df[column].isnull().sum() < len(wiki_movies_df) * 0.9]
# Out:
# ['url',
#  'year',
#  'imdb_link',
#  'title',
#  'Screenplay by',
#  'Story by',
#  'Based on',
#  'Starring',
#  'Music by',
#  'Cinematography',
#  'Release date',
#  'Running time',
#  'Country',
#  'Language',
#  'Budget',
#  'Box office',
#  'Director',
#  'Distributor',
#  'Editor(s)',
#  'Producer(s)',
#  'Production company(s)',
#  'Written by',
#  'IMDB_id']

# %%
wiki_columns_to_keep = [column for column in wiki_movies_df.columns if wiki_movies_df[column].isnull().sum() < len(wiki_movies_df) * 0.9]

wiki_movies_df = wiki_movies_df[wiki_columns_to_keep]

# %%
wiki_movies_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7033 entries, 0 to 7075
# Data columns (total 23 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   url                    7033 non-null   object
#  1   year                   7033 non-null   int64
#  2   imdb_link              7033 non-null   object
#  3   title                  7032 non-null   object
#  4   Screenplay by          2307 non-null   object
#  5   Story by               996 non-null    object
#  6   Based on               2181 non-null   object
#  7   Starring               6849 non-null   object
#  8   Music by               6440 non-null   object
#  9   Cinematography         6342 non-null   object
#  10  Release date           7001 non-null   object
#  11  Running time           6892 non-null   object
#  12  Country                6797 non-null   object
#  13  Language               6789 non-null   object
# ...

# %%
wiki_movies_df['Box office'].head()
# Out:
# 0       $21.4 million
# 1        $2.7 million
# 2         $57,718,089
# 3          $7,331,647
# 4    $6,939,946 (USA)
# Name: Box office, dtype: object

# %%
wiki_movies_df.dtypes
# Out:
# url                      object
# year                      int64
# imdb_link                object
# title                    object
# Screenplay by            object
# Story by                 object
# Based on                 object
# Starring                 object
# Music by                 object
# Cinematography           object
# Release date             object
# Running time             object
# Country                  object
# Language                 object
# Budget                   object
# Box office               object
# Director                 object
# Distributor              object
# Editor(s)                object
# Producer(s)              object
# Production company(s)    object
# Written by               object
# IMDB_id                  object
# dtype: object

# %%
box_office = wiki_movies_df['Box office'].dropna()

box_office
# Out:
# 0          $21.4 million
# 1           $2.7 million
# 2            $57,718,089
# 3             $7,331,647
# 4       $6,939,946 (USA)
#               ...
# 7070       $19.4 million
# 7071       $41.9 million
# 7072       $76.1 million
# 7073       $38.4 million
# 7074        $5.5 million
# Name: Box office, Length: 5485, dtype: object

# %% [markdown]
# # regex only work on strings
#
# > .map( )

# %%
def not_string(x):
    return type(x) != str

box_office[box_office.map(not_string)]
# Out:
# 34                           [US$, 4,212,828]
# 54      [$6,698,361 (, United States, ), [2]]
# 74                    [$6,488,144, (US), [1]]
# 126                [US$1,531,489, (domestic)]
# 130                          [US$, 4,803,039]
#                         ...
# 6980               [$99.6, million, [4], [5]]
# 6994                   [$365.6, million, [1]]
# 6995                         [$53.8, million]
# 7015                     [$435, million, [7]]
# 7048                   [$529.3, million, [4]]
# Name: Box office, Length: 135, dtype: object

# %% [markdown]
# # lambda function
#
# > lambda *arguments: expression*
# > automatically returns a variable

# %%
box_office[box_office.map(lambda x: type(x) != str)]
# Out:
# 34                           [US$, 4,212,828]
# 54      [$6,698,361 (, United States, ), [2]]
# 74                    [$6,488,144, (US), [1]]
# 126                [US$1,531,489, (domestic)]
# 130                          [US$, 4,803,039]
#                         ...
# 6980               [$99.6, million, [4], [5]]
# 6994                   [$365.6, million, [1]]
# 6995                         [$53.8, million]
# 7015                     [$435, million, [7]]
# 7048                   [$529.3, million, [4]]
# Name: Box office, Length: 135, dtype: object

# %% [markdown]
# # use blank space as separator along with join
# > .join( )

# %%
box_office = box_office.apply(lambda x: ' '.join(x) if type(x) == list else x)

# %% [markdown]
# # re module
# ## built in Python module for regex

# %%
#import re

# %%
box_office
# Out:
# 0          $21.4 million
# 1           $2.7 million
# 2            $57,718,089
# 3             $7,331,647
# 4       $6,939,946 (USA)
#               ...
# 7070       $19.4 million
# 7071       $41.9 million
# 7072       $76.1 million
# 7073       $38.4 million
# 7074        $5.5 million
# Name: Box office, Length: 5485, dtype: object

# %%
box_office_form1 = r'\$\s*\d+\.?\d*\s*[mb]illi?on'

# %% [markdown]
# # count values that match regex form
# > .str.contains(flags=re.IGNORECASE, na=False)

# %%
# count total returned as true with .sum()
box_office.str.contains(box_office_form1, flags=re.IGNORECASE, na=False).sum()
# Out:
# 3896

# %%
box_office_form2 = r'\$\s*\d{1,3}(?:[,\.]\d{3})+(?!\s[mb]illion)'

box_office.str.contains(box_office_form2, flags=re.IGNORECASE, na=False).sum()
# Out:
# 1559

# %%
matches_form_one = box_office.str.contains(box_office_form1, flags=re.IGNORECASE, na=False)
matches_form_two = box_office.str.contains(box_office_form2, flags=re.IGNORECASE, na=False)

# %%
matches_form_one
# Out:
# 0        True
# 1        True
# 2       False
# 3       False
# 4       False
#         ...
# 7070     True
# 7071     True
# 7072     True
# 7073     True
# 7074     True
# Name: Box office, Length: 5485, dtype: bool

# %% [markdown]
# # check which entries do not fit expected format(s)
#
# > ~ negation operator (tilde)
# > & logical AND (ampersand)
# > | logical OR (pipe)

# %%
box_office[~matches_form_one & ~matches_form_two]
# Out:
# 600                      $5000 (US)
# 1070                     35,254,617
# 1480                     £3 million
# 1865                   ¥1.1 billion
# 2032                            N/A
# 2091                           $309
# 2665    926,423 admissions (France)
# 3631                            TBA
# 3879       CN¥3.650 million (China)
# 4116                     £7,385,434
# 4306                            $30
# 4561        $45.2k (only in Turkey)
# 5447                          £2.56
# 5784                       413 733$
# 6013                        Unknown
# 6369                          $111k
# 6370                           $588
# 6593                 less than $372
# 6843                        8 crore
# Name: Box office, dtype: object

# %%
box_office = box_office.str.replace(r'\$.*[-—–](?![a-z])', '$', regex=True)

# %% [markdown]
# # extract
# > .str.extract( )
# > returns a DataFrame where every column is the data that matches a capture group

# %%
box_office.str.extract(f'({box_office_form1}|{box_office_form2})')
# Out:
#                   0
# 0     $21.4 million
# 1      $2.7 million
# 2       $57,718,089
# 3        $7,331,647
# 4        $6,939,946
# ...             ...
# 7070  $19.4 million
# 7071  $41.9 million
# 7072  $76.1 million
# 7073  $38.4 million
# 7074   $5.5 million
#
# [5485 rows x 1 columns]

# %% [markdown]
# # function to convert to numeric values
# > re.match(*pattern, string*)
# >
# > re.sub(*pattern, replacement_string, string*)

# %%
def parse_dollars(s):
    # if s is not a string, return NaN
    if type(s) != str:
        return np.nan
    
    # if input is of the form $###.# million
    if re.match(r'\$\s*\d+\.?\d*\s*milli?on', s, flags=re.IGNORECASE):
        
        # remove dollar sign and " million"
        s = re.sub('\$|\s|[a-zA-Z]','', s)
        
        # convert to float and multiply by a million
        value = float(s) * 10**6
        
        # return value
        return value
    
    # if input is of the form $###.# billion
    elif re.match(r'\$\s*\d+\.?\d*\s*billi?on', s, flags=re.IGNORECASE):
        
        # remove dollar sign and " billion"
        s = re.sub('\$|\s|[a-zA-Z]','', s)
        
        # convert to float and multiply by a billion
        value = float(s) * 10**9
        
        # return value
        return value
    
    # if input is of the form $###,###,###
    elif re.match(r'\$\s*\d{1,3}(?:[,\.]\d{3})+(?!\s[mb]illion)', s, flags=re.IGNORECASE):
        
        # remove dollar sign and commas
        s = re.sub('\$|,','', s)
        
        # convert to float
        value = float(s)
        
        # return value
        return value
    
    # otherwise, return NaN
    else:
        return np.nan

# %%
wiki_movies_df['box_office'] = box_office.str.extract(f'({box_office_form1}|{box_office_form2})', flags=re.IGNORECASE)[0].apply(parse_dollars)

# %%
wiki_movies_df['box_office'].head(10)
# Out:
# 0    21400000.0
# 1     2700000.0
# 2    57718089.0
# 3     7331647.0
# 4     6939946.0
# 5           NaN
# 6           NaN
# 7           NaN
# 8           NaN
# 9      855810.0
# Name: box_office, dtype: float64

# %%
wiki_movies_df.drop('Box office', axis=1, inplace=True)

# %%
wiki_movies_df.head()
# Out:
#                                                  url  year  \
# 0  https://en.wikipedia.org/wiki/The_Adventures_o...  1990
# 1  https://en.wikipedia.org/wiki/After_Dark,_My_S...  1990
# 2   https://en.wikipedia.org/wiki/Air_America_(film)  1990
# 3    https://en.wikipedia.org/wiki/Alice_(1990_film)  1990
# 4      https://en.wikipedia.org/wiki/Almost_an_Angel  1990
#
#                                imdb_link                            title  \
# 0  https://www.imdb.com/title/tt0098987/  The Adventures of Ford Fairlane
# 1  https://www.imdb.com/title/tt0098994/             After Dark, My Sweet
# 2  https://www.imdb.com/title/tt0099005/                      Air America
# 3  https://www.imdb.com/title/tt0099012/                            Alice
# 4  https://www.imdb.com/title/tt0099018/                  Almost an Angel
#
#                                 Screenplay by                     Story by  \
# 0  [David Arnott, James Cappe, Daniel Waters]  [David Arnott, James Cappe]
# ...

# %% [markdown]
# # budget

# %%
wiki_movies_df['Budget'].tail(10)

# %%
budget = wiki_movies_df['Budget'].dropna()

# %%
budget = budget.map(lambda x: ' '.join(x) if type(x) == list else x)

# %%
budget = budget.str.replace(r'\$.*[-—–](?![a-z])', '$', regex=True)

# %%
matches_form_one = budget.str.contains(box_office_form1, flags=re.IGNORECASE, na=False)
matches_form_two = budget.str.contains(box_office_form2, flags=re.IGNORECASE, na=False)
budget = budget.str.replace(r'\[\d+\]\s*', '')
budget[~matches_form_one & ~matches_form_two]
# Out:
# C:\Anaconda\envs\PythonData\lib\site-packages\ipykernel_launcher.py:3: FutureWarning: The default value of regex will change from True to False in a future version.
#   This is separate from the ipykernel package so we can avoid doing imports until
# 136                         Unknown
# 204     60 million Norwegian Kroner
# 478                         Unknown
# 1226                        Unknown
# 1278                            HBO
# 1374                     £6,000,000
# 1397                     13 million
# 1480                   £2.8 million
# 1734                   CAD2,000,000
# 1913     PHP 85 million (estimated)
# 1948                    102,888,900
# 1953                   3,500,000 DM
# 1973                     ₤2,300,874
# 2281                     $14 milion
# 2451                     ₤6,350,000
# 3144                   € 40 million
# 3418                        $218.32
# 3802                   £4.2 million
# 3906                            N/A
# ...

# %%
budget[~matches_form_one & ~matches_form_two].count()
# Out:
# 32

# %%
wiki_movies_df['budget'] = budget.str.extract(f'({box_office_form1}|{box_office_form2})', flags=re.IGNORECASE)[0].apply(parse_dollars)
wiki_movies_df.drop('Budget', axis=1, inplace=True)

# %% [markdown]
# # release date

# %%
release_date = wiki_movies_df['Release date'].dropna().apply(lambda x: ' '.join(x) if type(x) == list else x)

# %%
release_date.head(10)
# Out:
# 0                         July 11, 1990 ( 1990-07-11 )
# 1    May 17, 1990 ( 1990-05-17 ) (Cannes Film Marke...
# 2                       August 10, 1990 ( 1990-08-10 )
# 3                     December 25, 1990 ( 1990-12-25 )
# 4                                    December 19, 1990
# 5                        March 22, 1990 ( 1990-03-22 )
# 6    October 6, 1990 ( 1990-10-06 ) ( New York Film...
# 7                         March 8, 1991 ( 1991-03-08 )
# 8                         March 7, 1990 ( 1990-03-07 )
# 9                            February 23, 1990 ( USA )
# Name: Release date, dtype: object

# %%
release_date.tail(10)
# Out:
# 7066    November 26, 2018 ( 2018-11-26 ) ( Empire, Lei...
# 7067    December 3, 2018 ( 2018-12-03 ) ( Sony Center ...
# 7068     December 21, 2018 ( 2018-12-21 ) (United States)
# 7069     December 21, 2018 ( 2018-12-21 ) (United States)
# 7070    10 May 2018 ( 2018-05-10 ) ( Cannes ) 8 June 2...
# 7071     December 25, 2018 ( 2018-12-25 ) (United States)
# 7072    December 11, 2018 ( 2018-12-11 ) ( Samuel Gold...
# 7073    November 8, 2018 ( 2018-11-08 ) ( AFI Fest ) D...
# 7074    August 31, 2018 ( 2018-08-31 ) ( Telluride ) D...
# 7075                      28 December 2018 ( 2018-12-28 )
# Name: Release date, dtype: object

# %%
#date_form_1 = r'\D\s\d{1,2}\,\d{4}'
#date_form_2 =
#date_form_3 = r'\D\d{4)'
#date_form_4 = r'\d{4)'

# %%
date_form_one = r'(?:January|February|March|April|May|June|July|August|September|October|November|December)\s[123]?\d,\s\d{4}'
date_form_two = r'\d{4}.[01]\d.[0123]\d'
date_form_three = r'(?:January|February|March|April|May|June|July|August|September|October|November|December)\s\d{4}'
date_form_four = r'\d{4}'

# %%
release_date.str.extract(f'({date_form_one}|{date_form_two}|{date_form_three}|{date_form_four})', flags=re.IGNORECASE)

# %% [markdown]
# # to_datetime( )
# infer_datetime_format=True

# %%
wiki_movies_df['release_date'] = pd.to_datetime(release_date.str.extract(f'({date_form_one}|{date_form_two}|{date_form_three}|{date_form_four})')[0], infer_datetime_format=True)

# %%
wiki_movies_df['release_date'].tail()
# Out:
# 7071   2018-12-25
# 7072   2018-12-11
# 7073   2018-11-08
# 7074   2018-08-31
# 7075   2018-12-01
# Name: release_date, dtype: datetime64[ns]

# %% [markdown]
# # running time

# %%
running_time = wiki_movies_df['Running time'].dropna().apply(lambda x: ' '.join(x) if type(x) == list else x)

# %%
running_time
# Out:
# 0                                 102 minutes
# 1                                 114 minutes
# 2                                 113 minutes
# 3                                 106 minutes
# 4                                  95 minutes
#                         ...
# 7071                               90 minutes
# 7072                              132 minutes
# 7073                              120 minutes
# 7074                              123 minutes
# 7075    Variable; 90 minutes for default path
# Name: Running time, Length: 6892, dtype: object

# %%
running_time.str.contains(r'^\d*\s*minutes$', flags=re.IGNORECASE, na=False).sum()
# Out:
# 6528

# %%
running_time[running_time.str.contains(r'^\d*\s*minutes$', flags=re.IGNORECASE, na=False) != True]
# Out:
# 9                                                 102 min
# 26                                                 93 min
# 28                                                32 min.
# 34                                                101 min
# 35                                                 97 min
#                               ...
# 6500       114 minutes [1] 120 minutes (extended edition)
# 6643                                             104 mins
# 6709    90 minutes (theatrical) [1] 91 minutes (unrate...
# 7057    108 minutes (Original cut) 98 minutes (UK cut)...
# 7075                Variable; 90 minutes for default path
# Name: Running time, Length: 364, dtype: object

# %%
running_time[running_time.str.contains(r'\d*\s*m', flags=re.IGNORECASE, na=False) != True]
# Out:
# 1551     varies
# 3925    4 hours
# Name: Running time, dtype: object

# %%
running_time_extract = running_time.str.extract(r'(\d+)\s*ho?u?r?s?\s*(\d*)|(\d+)\s*m')

# %% [markdown]
# > .to_numeric( )
# > .fillna( )

# %%
running_time_extract = running_time_extract.apply(lambda col: pd.to_numeric(col, errors='coerce')).fillna(0)

# %% [markdown]
# apply a function that will convert the hour capture groups and minute capture groups to minutes if the pure minutes capture group is zero

# %%
wiki_movies_df['running_time'] = running_time_extract.apply(lambda row: row[0]*60 + row[1] if row[2] == 0 else row[2], axis=1)

# %%
wiki_movies_df.drop('Running time', axis=1, inplace=True)

# %%
wiki_movies_df.head(10)
# Out:
#                                                  url  year  \
# 0  https://en.wikipedia.org/wiki/The_Adventures_o...  1990
# 1  https://en.wikipedia.org/wiki/After_Dark,_My_S...  1990
# 2   https://en.wikipedia.org/wiki/Air_America_(film)  1990
# 3    https://en.wikipedia.org/wiki/Alice_(1990_film)  1990
# 4      https://en.wikipedia.org/wiki/Almost_an_Angel  1990
# 5        https://en.wikipedia.org/wiki/The_Ambulance  1990
# 6  https://en.wikipedia.org/wiki/American_Dream_(...  1990
# 7  https://en.wikipedia.org/wiki/American_Ninja_4...  1990
# 8     https://en.wikipedia.org/wiki/Andre%27s_Mother  1990
# 9    https://en.wikipedia.org/wiki/Angel_Town_(film)  1990
#
#                                imdb_link                               title  \
# 0  https://www.imdb.com/title/tt0098987/     The Adventures of Ford Fairlane
# 1  https://www.imdb.com/title/tt0098994/                After Dark, My Sweet
# 2  https://www.imdb.com/title/tt0099005/                         Air America
# ...
